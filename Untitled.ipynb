# %%
from mem0_config import memory_agent
# Out:
# Configuration validation error: 1 validation error for MemoryConfig
# vector_store
#   Value error, 'cluster_url' must be provided. [type=value_error, input_value={'collection_name': 'conv...dding_model_dims': 1536}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/value_error
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from mem0_config import memory_agent
#
# File N:\My Project\CoversationalAI\ConversationalAI\mem0_config.py:42
#       8 config = {
#       9     # Vector Store - Weaviate
#      10     "vector_store": {
#    (...)     38     # "custom_fact_extraction_prompt": "Extract key facts and preferences from the conversation",
#      39 }
#      41 # Initialize Memory
# ---> 42 memory_agent = Memory.from_config(config)
#
# ...
